# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.101.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.11/site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/lib/python3.11/site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Downloading openai-1.101.0-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.8/810.8 kB 1.0 MB/s eta 0:00:0000:0100:01
# Downloading jiter-0.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.2/352.2 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: jiter, openai
# Successfully installed jiter-0.10.0 openai-1.101.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import base64
from openai import OpenAI

# === CONFIGURAÇÃO ===
client = OpenAI(api_key="COLOQUE AQUI SUA CHAVE")  # 🔁 Substitua com sua chave real
imagem_path = "diretório da imagem"                # 🔁 Nome/caminho da imagem local

# === Função para codificar imagem em base64 ===
def carregar_imagem_base64(caminho):
    with open(caminho, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# === Função para interpretar o diagrama ER ===
def interpretar_diagrama_er(imagem_base64):
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": (
                    "Você é um especialista em banco de dados. Sua tarefa é interpretar um diagrama Entidade-Relacionamento (ER) "
                    "a partir de uma imagem e gerar a modelagem lógica correspondente. "
                    "Liste as entidades, atributos, chaves primárias (PK) e estrangeiras (FK)."
                )
            },
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": (
                            "A imagem a seguir mostra um diagrama ER. Por favor, converta-o em uma modelagem lógica (schema relacional), "
                            "listando todas as entidades com seus atributos, destacando as chaves primárias (PK) e estrangeiras (FK)."
                        )
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{imagem_base64}"
                        }
                    }
                ]
            }
        ],
        max_tokens=1000
    )
    return response.choices[0].message.content

# === Execução principal ===
if __name__ == "__main__":
    imagem_base64 = carregar_imagem_base64(imagem_path)
    resultado = interpretar_diagrama_er(imagem_base64)
    print("\n=== MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===\n")
    print(resultado)
# Out:
# === MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===
#
# A modelagem lógica derivada do diagrama ER apresentado é a seguinte:
#
# ### Entidade: EMPLOYEE
# - **Atributos:**
#   - Ssn (PK)
#   - Fname
#   - Minit
#   - Lname
#   - Bdate
#   - Address
#   - Sex
#   - Salary
#   - Dno (FK)
#
# ### Entidade: DEPARTMENT
# - **Atributos:**
#   - Number (PK)
#   - Name
#   - Locations
#
# ### Entidade: PROJECT
# - **Atributos:**
#   - Number (PK)
#   - Name
#   - Location
#   - Dno (FK)
#
# ### Entidade: DEPENDENT
# - **Atributos:**
#   - Employee_Ssn (PK, FK)
#   - Name (PK)
#   - Sex
#   - Birth_date
#   - Relationship
#
# ### Relacionamento: WORKS_FOR
# - **Atributos:**
#   - Employee_Ssn (PK, FK)
#   - Department_Number (PK, FK)
#   - Start_date
#
# ### Relacionamento: MANAGES
# - **Atributos:**
#   - Employee_Ssn (PK, FK)
#   - Department_Number (PK, FK)
#   - Start_date
#
# ### Relacionamento: WORKS_ON
# - **Atributos:**
#   - Employee_Ssn (PK, FK)
#   - Project_Number (PK, FK)
#   - Hours
#
# ### Relacionamento: CONTROLS
# - **Atributos:**
#   - Department_Number (PK, FK)
#   - Project_Number (PK, FK)
#
# ### Relacionamento: SUPERVISION
# - **Atributos:**
#   - Supervisor_Ssn (PK, FK)
#   - Supervisee_Ssn (PK, FK)
#
# Esta modelagem lógica possui as tabelas resultantes de entidades e alguns relacionamentos do diagrama ER. As chaves primárias (PK) e estrangeiras (FK) são indicadas para assegurar consistência e integridade referencial no banco de dados.

# %% [markdown]
# # Código Final

# %% [markdown]
# ## Prompt 1 - gpt-4o

# %%
import base64
from openai import OpenAI

# === CONFIGURAÇÃO ===
client = OpenAI(api_key="COLOQUE AQUI SUA CHAVE")  # 🔁 Substitua com sua chave real
imagem_path = "diretório da imagem"                # 🔁 Nome/caminho da imagem local

# === Função para codificar imagem em base64 ===
def carregar_imagem_base64(caminho):
    with open(caminho, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# === Função para interpretar o diagrama ER ===
def interpretar_diagrama_er(imagem_base64):
    prompt = (
        "Analise a imagem contendo um Diagrama Entidade-Relacionamento (ER) e converta-a para um esquema lógico relacional em formato JSON estruturado.\n\n"
        "Instruções:\n"
        "Para cada entidade, gere uma entrada com:\n\n"
        "- \"attributes\": lista com todos os atributos da tabela\n"
        "- \"pk\": chave primária como lista (mesmo que contenha apenas um atributo)\n"
        "- \"fk\": lista de chaves estrangeiras (se existirem)\n\n"
        "Caso não existam chaves estrangeiras, omita o campo \"fk\".\n"
        "Use nomes significativos, mantendo consistência com o diagrama original.\n\n"
        "O modelo de saída deve seguir rigorosamente o seguinte formato:\n"
        "{\n"
        "  \"Entities\": {\n"
        "    \"EntityName\": {\n"
        "      \"attributes\": [\"x\", \"y\", \"z\"],\n"
        "      \"pk\": [\"a\"],\n"
        "      \"fk\": [\"b\", \"c\"]\n"
        "    },\n"
        "    \"AnotherEntity\": {\n"
        "      \"attributes\": [\"m\", \"n\"],\n"
        "      \"pk\": [\"m\"]\n"
        "    }\n"
        "  }\n"
        "}"
    )

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": "Você é um assistente especialista em banco de dados relacionais e transformação de diagramas ER para modelo lógico."
            },
            {
                "role": "user",
                "content": [
                    { "type": "text", "text": prompt },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{imagem_base64}"
                        }
                    }
                ]
            }
        ],
        max_tokens=1500,
        temperature=0
    )

    return response.choices[0].message.content

# === Execução principal ===
if __name__ == "__main__":
    imagem_base64 = carregar_imagem_base64(imagem_path)
    resultado = interpretar_diagrama_er(imagem_base64)
    print("\n=== MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===\n")
    print(resultado)
# Out:
# === MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===
#
# ```json
# {
#   "Entities": {
#     "EMPLOYEE": {
#       "attributes": ["Fname", "Minit", "Lname", "Ssn", "Bdate", "Address", "Salary", "Sex"],
#       "pk": ["Ssn"]
#     },
#     "DEPARTMENT": {
#       "attributes": ["Name", "Number", "Locations"],
#       "pk": ["Number"]
#     },
#     "PROJECT": {
#       "attributes": ["Name", "Number", "Location"],
#       "pk": ["Number"]
#     },
#     "DEPENDENT": {
#       "attributes": ["Name", "Sex", "Birth_date", "Relationship"],
#       "pk": ["Name"]
#     },
#     "WORKS_FOR": {
#       "attributes": ["Employee_Ssn", "Department_Number", "Start_date"],
#       "pk": ["Employee_Ssn", "Department_Number"],
#       "fk": ["Employee_Ssn", "Department_Number"]
#     },
#     "MANAGES": {
#       "attributes": ["Manager_Ssn", "Department_Number", "Start_date"],
#       "pk": ["Manager_Ssn", "Department_Number"],
#       "fk": ["Manager_Ssn", "Department_Number"]
#     },
#     "WORKS_ON": {
#       "attributes": ["Worker_Ssn", "Project_Number", "Hours"],
#       "pk": ["Worker_Ssn", "Project_Number"],
#       "fk": ["Worker_Ssn", "Project_Number"]
#     },
#     "CONTROLS": {
#       "attributes": ["Department_Number", "Project_Number"],
#       "pk": ["Department_Number", "Project_Number"],
#       "fk": ["Department_Number", "Project_Number"]
#     },
#     "SUPERVISION": {
#       "attributes": ["Supervisor_Ssn", "Supervisee_Ssn"],
#       "pk": ["Supervisor_Ssn", "Supervisee_Ssn"],
#       "fk": ["Supervisor_Ssn", "Supervisee_Ssn"]
#     },
#     "DEPENDENTS_OF": {
#       "attributes": ["Employee_Ssn", "Dependent_Name"],
#       "pk": ["Employee_Ssn", "Dependent_Name"],
#       "fk": ["Employee_Ssn", "Dependent_Name"]
#     }
#   }
# }
# ```

# %% [markdown]
# ## prompt 1 - gpt-5

# %%
import base64
from openai import OpenAI

# === CONFIGURAÇÃO ===
client = OpenAI(api_key="COLOQUE AQUI SUA CHAVE")  # 🔁 Substitua com sua chave real
imagem_path = "diretório da imagem"                # 🔁 Nome/caminho da imagem local

# === Função para codificar imagem em base64 ===
def carregar_imagem_base64(caminho):
    with open(caminho, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# === Função para interpretar o diagrama ER ===
def interpretar_diagrama_er(imagem_base64):
    prompt = (
        "Analise a imagem contendo um Diagrama Entidade-Relacionamento (ER) e converta-a para um esquema lógico relacional em formato JSON estruturado.\n\n"
        "Instruções:\n"
        "Para cada entidade, gere uma entrada com:\n\n"
        "- \"attributes\": lista com todos os atributos da tabela\n"
        "- \"pk\": chave primária como lista (mesmo que contenha apenas um atributo)\n"
        "- \"fk\": lista de chaves estrangeiras (se existirem)\n\n"
        "Caso não existam chaves estrangeiras, omita o campo \"fk\".\n"
        "Use nomes significativos, mantendo consistência com o diagrama original.\n\n"
        "O modelo de saída deve seguir rigorosamente o seguinte formato:\n"
        "{\n"
        "  \"Entities\": {\n"
        "    \"EntityName\": {\n"
        "      \"attributes\": [\"x\", \"y\", \"z\"],\n"
        "      \"pk\": [\"a\"],\n"
        "      \"fk\": [\"b\", \"c\"]\n"
        "    },\n"
        "    \"AnotherEntity\": {\n"
        "      \"attributes\": [\"m\", \"n\"],\n"
        "      \"pk\": [\"m\"]\n"
        "    }\n"
        "  }\n"
        "}"
    )

    response = client.chat.completions.create(
        model="gpt-5",
        messages=[
            {
                "role": "system",
                "content": "Você é um assistente especialista em banco de dados relacionais e transformação de diagramas ER para modelo lógico."
            },
            {
                "role": "user",
                "content": [
                    { "type": "text", "text": prompt },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{imagem_base64}"
                        }
                    }
                ]
            }
        ]
    )

    return response.choices[0].message.content

# === Execução principal ===
if __name__ == "__main__":
    imagem_base64 = carregar_imagem_base64(imagem_path)
    resultado = interpretar_diagrama_er(imagem_base64)
    print("\n=== MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===\n")
    print(resultado)
# Out:
# === MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===
#
# {
#   "Entities": {
#     "EMPLOYEE": {
#       "attributes": ["Fname", "Minit", "Lname", "Bdate", "Address", "Salary", "Ssn", "Sex", "Start_date", "Department_Number", "Supervisor_Ssn"],
#       "pk": ["Ssn"],
#       "fk": ["Department_Number", "Supervisor_Ssn"]
#     },
#     "DEPARTMENT": {
#       "attributes": ["Number", "Name", "Manager_Ssn"],
#       "pk": ["Number"],
#       "fk": ["Manager_Ssn"]
#     },
#     "PROJECT": {
#       "attributes": ["Number", "Name", "Location", "Controlling_Department"],
#       "pk": ["Number"],
#       "fk": ["Controlling_Department"]
#     },
#     "WORKS_ON": {
#       "attributes": ["Employee_Ssn", "Project_Number", "Hours"],
#       "pk": ["Employee_Ssn", "Project_Number"],
#       "fk": ["Employee_Ssn", "Project_Number"]
#     },
#     "DEPENDENT": {
#       "attributes": ["Employee_Ssn", "Name", "Sex", "Birth_date", "Relationship"],
#       "pk": ["Employee_Ssn", "Name"],
#       "fk": ["Employee_Ssn"]
#     },
#     "DEPT_LOCATIONS": {
#       "attributes": ["Department_Number", "Location"],
#       "pk": ["Department_Number", "Location"],
#       "fk": ["Department_Number"]
#     }
#   }
# }

# %% [markdown]
# ## prompt 2 - gpt-4o

# %%
import base64
from openai import OpenAI

# === CONFIGURAÇÃO ===
client = OpenAI(api_key="COLOQUE AQUI SUA CHAVE")  # 🔁 Substitua com sua chave real
imagem_path = "diretório da imagem"                # 🔁 Nome/caminho da imagem local

# === Função para codificar imagem em base64 ===
def carregar_imagem_base64(caminho):
    with open(caminho, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# === Função para interpretar o diagrama ER ===
def interpretar_diagrama_er(imagem_base64):
    prompt = (
        "Analise a imagem contendo um Diagrama Entidade-Relacionamento (ER) e converta-a para um esquema lógico relacional em formato JSON estruturado.\n\n"
       "Instruções:\n"
    "Para cada entidade ou relacionamento, gere uma entrada com:\n\n"
    "- \"attributes\": lista com todos os atributos da tabela\n"
    "- \"pk\": chave primária como lista (mesmo que contenha apenas um atributo)\n"
    "- \"fk\": lista de chaves estrangeiras (se existirem)\n\n"
    "Caso não existam chaves estrangeiras, omita o campo \"fk\".\n"
    "Use nomes significativos, mantendo consistência com o diagrama original.\n\n"
    "Utilize as regras abaixo para decisão por tabela própria, adição de coluna ou fusão de tabelas:\n\n"
    "Relacionamentos 1:1\n"
    "1. (0,1) — (0,1)\n"
    "Tabela própria: ± (pode ser usada)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "2. (0,1) — (1,1)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ± (pode ser usada)\n"
    "Fusão de tabelas: ✔ (preferida)\n\n"
    "3. (1,1) — (1,1)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ± (pode ser usada)\n"
    "Fusão de tabelas: ✔ (preferida)\n\n"
    "Relacionamentos 1:n\n"
    "1. (0,1) — (0,n)\n"
    "Tabela própria: ± (pode ser usada)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "2. (0,1) — (1,n)\n"
    "Tabela própria: ± (pode ser usada)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "3. (1,1) — (0,n)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "4. (1,1) — (1,n)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "Relacionamentos n:n\n"
    "1. (0,n) — (0,n)\n"
    "Tabela própria: ✔ (preferida)\n"
    "Adição de coluna: ✘ (não usar)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "2. (0,n) — (1,n)\n"
    "Tabela própria: ✔ (preferida)\n"
    "Adição de coluna: ✘ (não usar)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "3. (1,n) — (1,n)\n"
    "Tabela própria: ✔ (preferida)\n"
    "Adição de coluna: ✘ (não usar)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "O modelo de saída deve seguir rigorosamente o seguinte formato:\n"
    "{\n"
    "  \"Entities\": {\n"
    "    \"EntityName\": {\n"
    "      \"attributes\": [\"x\", \"y\", \"z\"],\n"
    "      \"pk\": [\"a\"],\n"
    "      \"fk\": [\"b\", \"c\"]\n"
    "    },\n"
    "    \"AnotherEntity\": {\n"
    "      \"attributes\": [\"m\", \"n\"],\n"
    "      \"pk\": [\"m\"]\n"
    "    }\n"
    "  }\n"
    "}"
    )

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": "Você é um assistente especialista em banco de dados relacionais e transformação de diagramas ER para modelo lógico."
            },
            {
                "role": "user",
                "content": [
                    { "type": "text", "text": prompt },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{imagem_base64}"
                        }
                    }
                ]
            }
        ],
        max_tokens=1500,
        temperature=0
    )

    return response.choices[0].message.content

# === Execução principal ===
if __name__ == "__main__":
    imagem_base64 = carregar_imagem_base64(imagem_path)
    resultado = interpretar_diagrama_er(imagem_base64)
    print("\n=== MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===\n")
    print(resultado)
# Out:
# === MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===
#
# ```json
# {
#   "Entities": {
#     "EMPLOYEE": {
#       "attributes": ["Fname", "Minit", "Lname", "Ssn", "Bdate", "Address", "Sex", "Salary", "Super_ssn", "Dno"],
#       "pk": ["Ssn"],
#       "fk": ["Super_ssn", "Dno"]
#     },
#     "DEPARTMENT": {
#       "attributes": ["Name", "Number", "Locations", "Mgr_ssn", "Mgr_start_date"],
#       "pk": ["Number"],
#       "fk": ["Mgr_ssn"]
#     },
#     "PROJECT": {
#       "attributes": ["Name", "Number", "Location", "Dnum"],
#       "pk": ["Number"],
#       "fk": ["Dnum"]
#     },
#     "DEPENDENT": {
#       "attributes": ["Dependent_name", "Sex", "Birth_date", "Relationship", "Essn"],
#       "pk": ["Dependent_name", "Essn"],
#       "fk": ["Essn"]
#     },
#     "WORKS_ON": {
#       "attributes": ["Essn", "Pno", "Hours"],
#       "pk": ["Essn", "Pno"],
#       "fk": ["Essn", "Pno"]
#     }
#   }
# }
# ```

# %% [markdown]
# ## prompt 2 - gpt 5

# %%
import base64
from openai import OpenAI

# === CONFIGURAÇÃO ===
client = OpenAI(api_key="COLOQUE AQUI SUA CHAVE")  # 🔁 Substitua com sua chave real
imagem_path = "diretório da imagem"                # 🔁 Nome/caminho da imagem local

# === Função para codificar imagem em base64 ===
def carregar_imagem_base64(caminho):
    with open(caminho, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# === Função para interpretar o diagrama ER ===
def interpretar_diagrama_er(imagem_base64):
    prompt = (
        "Analise a imagem contendo um Diagrama Entidade-Relacionamento (ER) e converta-a para um esquema lógico relacional em formato JSON estruturado.\n\n"
       "Instruções:\n"
    "Para cada entidade ou relacionamento, gere uma entrada com:\n\n"
    "- \"attributes\": lista com todos os atributos da tabela\n"
    "- \"pk\": chave primária como lista (mesmo que contenha apenas um atributo)\n"
    "- \"fk\": lista de chaves estrangeiras (se existirem)\n\n"
    "Caso não existam chaves estrangeiras, omita o campo \"fk\".\n"
    "Use nomes significativos, mantendo consistência com o diagrama original.\n\n"
    "Utilize as regras abaixo para decisão por tabela própria, adição de coluna ou fusão de tabelas:\n\n"
    "Relacionamentos 1:1\n"
    "1. (0,1) — (0,1)\n"
    "Tabela própria: ± (pode ser usada)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "2. (0,1) — (1,1)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ± (pode ser usada)\n"
    "Fusão de tabelas: ✔ (preferida)\n\n"
    "3. (1,1) — (1,1)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ± (pode ser usada)\n"
    "Fusão de tabelas: ✔ (preferida)\n\n"
    "Relacionamentos 1:n\n"
    "1. (0,1) — (0,n)\n"
    "Tabela própria: ± (pode ser usada)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "2. (0,1) — (1,n)\n"
    "Tabela própria: ± (pode ser usada)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "3. (1,1) — (0,n)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "4. (1,1) — (1,n)\n"
    "Tabela própria: ✘ (não usar)\n"
    "Adição de coluna: ✔ (preferida)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "Relacionamentos n:n\n"
    "1. (0,n) — (0,n)\n"
    "Tabela própria: ✔ (preferida)\n"
    "Adição de coluna: ✘ (não usar)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "2. (0,n) — (1,n)\n"
    "Tabela própria: ✔ (preferida)\n"
    "Adição de coluna: ✘ (não usar)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "3. (1,n) — (1,n)\n"
    "Tabela própria: ✔ (preferida)\n"
    "Adição de coluna: ✘ (não usar)\n"
    "Fusão de tabelas: ✘ (não usar)\n\n"
    "O modelo de saída deve seguir rigorosamente o seguinte formato:\n"
    "{\n"
    "  \"Entities\": {\n"
    "    \"EntityName\": {\n"
    "      \"attributes\": [\"x\", \"y\", \"z\"],\n"
    "      \"pk\": [\"a\"],\n"
    "      \"fk\": [\"b\", \"c\"]\n"
    "    },\n"
    "    \"AnotherEntity\": {\n"
    "      \"attributes\": [\"m\", \"n\"],\n"
    "      \"pk\": [\"m\"]\n"
    "    }\n"
    "  }\n"
    "}"
    )

    response = client.chat.completions.create(
        model="gpt-5",
        messages=[
            {
                "role": "system",
                "content": "Você é um assistente especialista em banco de dados relacionais e transformação de diagramas ER para modelo lógico."
            },
            {
                "role": "user",
                "content": [
                    { "type": "text", "text": prompt },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{imagem_base64}"
                        }
                    }
                ]
            }
        ]
    )

    return response.choices[0].message.content

# === Execução principal ===
if __name__ == "__main__":
    imagem_base64 = carregar_imagem_base64(imagem_path)
    resultado = interpretar_diagrama_er(imagem_base64)
    print("\n=== MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===\n")
    print(resultado)
# Out:
# === MODELAGEM LÓGICA (SCHEMA RELACIONAL) ===
#
# {
#   "Entities": {
#     "EMPLOYEE": {
#       "attributes": ["Ssn", "Fname", "Minit", "Lname", "Bdate", "Address", "Sex", "Salary", "DepartmentNumber", "Start_date", "Supervisor_ssn"],
#       "pk": ["Ssn"],
#       "fk": ["DepartmentNumber", "Supervisor_ssn"]
#     },
#     "DEPARTMENT": {
#       "attributes": ["Number", "Name", "Manager_ssn"],
#       "pk": ["Number"],
#       "fk": ["Manager_ssn"]
#     },
#     "DEPARTMENT_LOCATION": {
#       "attributes": ["DepartmentNumber", "Location"],
#       "pk": ["DepartmentNumber", "Location"],
#       "fk": ["DepartmentNumber"]
#     },
#     "PROJECT": {
#       "attributes": ["Number", "Name", "Location", "DepartmentNumber"],
#       "pk": ["Number"],
#       "fk": ["DepartmentNumber"]
#     },
#     "WORKS_ON": {
#       "attributes": ["EmployeeSsn", "ProjectNumber", "Hours"],
#       "pk": ["EmployeeSsn", "ProjectNumber"],
#       "fk": ["EmployeeSsn", "ProjectNumber"]
#     },
#     "DEPENDENT": {
#       "attributes": ["EmployeeSsn", "Name", "Sex", "Birth_date", "Relationship"],
#       "pk": ["EmployeeSsn", "Name"],
#       "fk": ["EmployeeSsn"]
#     }
#   }
# }
